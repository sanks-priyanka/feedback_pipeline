# %%
import requests

# %%
url = "https://raw.githubusercontent.com/ruch0401/public-endpoints/refs/heads/main/website_reviews.csv"
response_website = requests.get(url)

csv_content = response_website.text
dbutils.fs.put("dbfs:/FileStore/website_review.csv", csv_content, overwrite=True)
# Out:
# Wrote 71862 bytes.
# Out[2]: True

# %%
url = "https://raw.githubusercontent.com/ruch0401/public-endpoints/refs/heads/main/social_media.json"
response_social_media = requests.get(url)

json_content = response_social_media.text
dbutils.fs.put("dbfs:/FileStore/social_media.json", json_content, overwrite=True)
# Out:
# Wrote 119003 bytes.
# Out[3]: True

# %%
# URL of the raw JSON file
url = "https://raw.githubusercontent.com/ruch0401/public-endpoints/refs/heads/main/support_tickets.json"
response_support_ticket = requests.get(url)

json_content = response_support_ticket.text
dbutils.fs.put("dbfs:/FileStore/support_ticket.json", json_content, overwrite=True)
# Out:
# Wrote 154645 bytes.
# Out[4]: True

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("FeedbackPipeline").getOrCreate()

# %%
df_website = spark.read.option("header", "true").csv("/FileStore/website_review.csv")
df_social_media = spark.read.option("multiline", "true").json("/FileStore/social_media.json")
df_support_ticket = spark.read.option("multiline", "true").json("/FileStore/support_ticket.json")

# %%
website_reviews = df_website.count()
print(f"Website reviews: {website_reviews}")

social_media_reviews = df_social_media.count()
print(f"Social Media reviews: {social_media_reviews}")

support_ticket = df_support_ticket.count()
print(f"Support ticket : {support_ticket}")
# Out:
# Website reviews: 500
# Social Media reviews: 500
# Support ticket : 500

# %%
df_website = (df_website
              .withColumnRenamed("review_id", "feedback_id")
              .withColumnRenamed("review", "feedback_text")
              .withColumn("feedback_on", to_timestamp("timestamp", "yyyy-MM-dd'T'HH:mm:ss"))
              .withColumnRenamed("customer_id","user_id")
              .withColumn("source", lit("Website Review"))
              .withColumn("user_name", lit(None))
              .withColumn("user_email", lit(None))
              .withColumn("platform", lit("Website name"))
)
df_website.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feedback_id</th><th>user_id</th><th>rating</th><th>feedback_text</th><th>timestamp</th><th>feedback_on</th><th>source</th><th>user_name</th><th>user_email</th><th>platform</th></tr></thead><tbody><tr><td>R0000</td><td>9fb1e99f-404a-4794-9b43-baf741d35d5b</td><td>2</td><td>Thus wrong operation bad party other energy economy these hundred Mr.</td><td>2025-03-23T02:25:16</td><td>2025-03-23T02:25:16.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0001</td><td>53eb38dc-d17f-4463-a322-5a26d5a9229b</td><td>1</td><td>You seat picture return different door hot stop moment.</td><td>2025-01-25T18:11:45</td><td>2025-01-25T18:11:45.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0002</td><td>23104eff-cdce-436d-aaf7-cb8174451fa3</td><td>1</td><td>Road watch much improve about increase world middle myself low career.</td><td>2025-03-25T06:23:36</td><td>2025-03-25T06:23:36.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0003</td><td>db7a1114-6810-4cea-82f6-9cea23bb17a5</td><td>2</td><td>Just against source blue other sure theory me idea.</td><td>2025-03-16T10:45:34</td><td>2025-03-16T10:45:34.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0004</td><td>765cc8b1-cbfe-459e-868f-76daa015319b</td><td>3</td><td>Baby small water young fish fine table scene difficult.</td><td>2025-04-05T08:46:10</td><td>2025-04-05T08:46:10.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0005</td><td>8c2bee92-a057-40e6-95b4-4fb7ac340126</td><td>1</td><td>Seem up push suffer final forward north address beat.</td><td>2025-01-18T23:10:32</td><td>2025-01-18T23:10:32.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0006</td><td>a1bdf10f-bc3f-489a-b04a-c09bba5f505a</td><td>2</td><td>Police system white begin everyone floor morning family same poor cell character.</td><td>2025-02-12T00:15:29</td><td>2025-02-12T00:15:29.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0007</td><td>d32dd2c4-7afb-4b91-8f86-cc8f73e2c60c</td><td>1</td><td>Condition customer end capital American perform company design policy throw war school form.</td><td>2025-03-27T07:35:25</td><td>2025-03-27T07:35:25.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0008</td><td>8e0eacab-6525-4f22-a3e4-de1234fb6e02</td><td>4</td><td>Population kitchen law Republican fall pass almost spring like mention expect.</td><td>2025-03-31T08:30:49</td><td>2025-03-31T08:30:49.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0009</td><td>db342837-35f4-4746-a8cd-27f018de682e</td><td>3</td><td>After score situation born real town worker try use result enter bill summer pattern most break.</td><td>2025-04-02T11:19:24</td><td>2025-04-02T11:19:24.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0010</td><td>512a834e-3786-4c0c-ba1d-88be1705d667</td><td>4</td><td>Morning each pick arm trip risk these could quite.</td><td>2025-01-17T13:15:57</td><td>2025-01-17T13:15:57.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0011</td><td>7e9692fa-272a-42ff-ad00-51b728e61a43</td><td>3</td><td>Billion find ask executive each number dinner society water culture ask government two TV size ok.</td><td>2025-03-04T09:28:01</td><td>2025-03-04T09:28:01.000+0000</td><td>Website Review</td><td>null</td><td>null</td><td>Website name</td></tr><tr><td>R0012</td><td>ca68f223-eaf5-4e35-a704-410afde30d75</td><td>2</td><td>Scene story peace exist debate kind report claim perhaps better.</td><td>2025-02-01T02:29:13</td ...

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

# Define the window
window_spec = Window.partitionBy("user_id").orderBy(df_website["feedback_on"].desc())

# Add a row number: 1 = latest record
df_website = df_website.withColumn("row_num", row_number().over(window_spec)) \
             .filter("row_num == 1") \
             .drop("row_num")

df_website.count()
# Out:
# Out[9]: 500

# %%
df_social_media = (df_social_media
                   .withColumnRenamed("id", "feedback_id")
                   .withColumnRenamed("content", "feedback_text")
                   .withColumn("feedback_on", to_timestamp("timestamp", "yyyy-MM-dd'T'HH:mm:ss"))
                   .withColumnRenamed("user","user_name")
                   .withColumn("source", lit("Social Media Review"))
                   .withColumn("user_id",lit(None))
                   .withColumn("user_email", lit(None))
                   )
df_social_media.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feedback_text</th><th>feedback_id</th><th>platform</th><th>timestamp</th><th>user_name</th><th>feedback_on</th><th>source</th><th>user_id</th><th>user_email</th></tr></thead><tbody><tr><td>Rate focus people participant face song. Firm difference forget with but peace quickly.</td><td>S0000</td><td>Facebook</td><td>2025-01-01T09:22:05</td><td>jmorris</td><td>2025-01-01T09:22:05.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Artist happy officer after nothing part discuss. Than least study glass only.</td><td>S0001</td><td>Twitter</td><td>2025-01-11T00:09:20</td><td>laura00</td><td>2025-01-11T00:09:20.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Scene here American although yeah. Father onto operation green weight. Expect yourself quality able.</td><td>S0002</td><td>Instagram</td><td>2025-03-23T03:21:06</td><td>brownmitchell</td><td>2025-03-23T03:21:06.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Great manager almost require always tell hit blue.</td><td>S0003</td><td>Facebook</td><td>2025-04-04T15:58:27</td><td>nicholas45</td><td>2025-04-04T15:58:27.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Decide many fire onto culture deep building pick. Mr among network. Director art approach hope trip happy thank.</td><td>S0004</td><td>Instagram</td><td>2025-04-10T09:44:19</td><td>anthonyvelasquez</td><td>2025-04-10T09:44:19.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Total any soon may respond debate. Mention local stop for final beyond across. Could big eat they.</td><td>S0005</td><td>Facebook</td><td>2025-03-20T14:13:48</td><td>fosterjoe</td><td>2025-03-20T14:13:48.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Specific on whether pressure line. Choose bar skin off office paper.</td><td>S0006</td><td>Instagram</td><td>2025-04-09T13:55:52</td><td>hernandezjustin</td><td>2025-04-09T13:55:52.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Toward receive dog skill.</td><td>S0007</td><td>Twitter</td><td>2025-03-31T03:06:58</td><td>scottevelyn</td><td>2025-03-31T03:06:58.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Environment senior training. Well year set upon wear.</td><td>S0008</td><td>Facebook</td><td>2025-04-13T23:24:01</td><td>donaldmaldonado</td><td>2025-04-13T23:24:01.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Science tax real suddenly visit hundred. Run through light.
# Argue road save magazine.</td><td>S0009</td><td>Facebook</td><td>2025-02-26T08:14:22</td><td>heathermckee</td><td>2025-02-26T08:14:22.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Where common consider food begin realize size hold. Kind sell machine beyond action somebody enough.</td><td>S0010</td><td>Twitter</td><td>2025-02-23T16:11:57</td><td>james49</td><td>2025-02-23T16:11:57.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Move heart officer sometimes less thus sign. Bill benefit test buy south lead property. Administration buy necessary service pull.</td><td>S0011</td><td>Instagram</td><td>2025-02-07T00:28:45</td><td>barbara13</td><td>2025-02-07T00:28:45.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>It dark as wrong across oil if. History other look Mrs often letter toward.</td><td>S0012</td><td>Facebook</td><td>2025-03-08T04:09:00</td><td>ychase</td><td>2025-03-08T04:09:00.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Laugh sister help parent. City remember couple nation other.</td><td>S0013</td><td>Twitter</td><td>2025-03-07T02:15:23</td><td>chall</td><td>2025-03-07T02:15:23.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Room statement parent between say. Evidence friend charge toward consumer present. Forget thought kind in oil space.</td><td>S0014</td><td>Facebook</td><td>2025-02-17T03:37:42</td><td>lisa91</td><td>2025-02-17T03:37:42.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Billion everything act gun natural career. Significant floor thus write throw anything. Man sing shake control.</td><td>S0015</td><td>Facebook</td><td>2025-03-15T15:43:16</td><td>allenvanessa</td><td>2025-03-15T15:43:16.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Likely here prove war effort. May share cover beyond. Interest region quite easy feel no.</td><td>S0016</td><td>Facebook</td><td>2025-02-03T08:01:44</td><td>curryalexandra</td><td>2025-02-03T08:01:44.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Appear role coach only second fish. Themselves agency need agree citizen.</td><td>S0017</td><td>Instagram</td><td>2025-03-02T14:49:55</td><td>juan89</td><td>2025-03-02T14:49:55.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Imagine lead see without. Possible week statement end.
# Central too side. Help ask share college.</td><td>S0018</td><td>Twitter</td><td>2025-04-12T02:17:45</td><td>kmills</td><td>2025-04-12T02:17:45.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Hotel bank its have south street. Move miss product pressure.</td><td>S0019</td><td>Twitter</td><td>2025-04-01T15:19:00</td><td>jlawrence</td><td>2025-04-01T15:19:00.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Film serious let. Else help run effort son or.
# Together kid response develop kid available social. Environment sense skin say official.</td><td>S0020</td><td>Twitter</td><td>2025-03-15T18:14:27</td><td>lwoods</td><td>2025-03-15T18:14:27.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Condition approach civil rich minute about agree. Letter want whom beat employee tree section surface.</td><td>S0021</td><td>Twitter</td><td>2025-02-21T18:43:07</td><td>xkaufman</td><td>2025-02-21T18:43:07.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Small difference up long instead must truth situation. Else will radio across next girl. Include energy center agent ok hour until.</td><td>S0022</td><td>Facebook</td><td>2025-01-06T07:48:20</td><td>johnsonstephen</td><td>2025-01-06T07:48:20.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Director heavy box break. Message ago meeting.</td><td>S0023</td><td>Instagram</td><td>2025-01-31T11:59:53</td><td>rharris</td><td>2025-01-31T11:59:53.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Economy land him mean very here foot. Court painting every standard perhaps interest include.</td><td>S0024</td><td>Twitter</td><td>2025-02-01T17:31:45</td><td>michaelbyrd</td><td>2025-02-01T17:31:45.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Society order moment brother discussion white. Four analysis evidence while market themselves other. Crime our people many run bag.</td><td>S0025</td><td>Instagram</td><td>2025-02-26T13:37:41</td><td>suzanne22</td><td>2025-02-26T13:37:41.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>At force candidate do war believe special. Well feeling majority certain author.</td><td>S0026</td><td>Twitter</td><td>2025-02-07T04:19:18</td><td>cindy21</td><td>2025-02-07T04:19:18.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>Far prevent sometimes stuff big. Foot

# %%
df_duplicates = df_social_media.groupBy("user_name") \
                  .count() \
                  .filter("count > 1")
df_duplicates.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>count</th></tr></thead><tbody><tr><td>rlewis</td><td>2</td></tr></tbody></table></div>

# %%
df_duplicates = df_duplicates.select("user_name")

# Step 2: Join back to original DataFrame to get full rows
df_duplicates = df_social_media.join(df_duplicates, on="user_name", how="inner")

# Step 3: Display
df_duplicates.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>feedback_text</th><th>feedback_id</th><th>platform</th><th>timestamp</th><th>feedback_on</th><th>source</th><th>user_id</th><th>user_email</th></tr></thead><tbody><tr><td>rlewis</td><td>Amount however only voice despite talk community. Know seven teacher series.</td><td>S0399</td><td>Instagram</td><td>2025-03-06T02:39:49</td><td>2025-03-06T02:39:49.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr><tr><td>rlewis</td><td>Production medical drug today later. Fill nature senior be sea. Mean his beyond ground require serious.</td><td>S0454</td><td>Facebook</td><td>2025-02-03T01:36:03</td><td>2025-02-03T01:36:03.000+0000</td><td>Social Media Review</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# Define the window
window_spec = Window.partitionBy("user_name").orderBy(df_social_media["feedback_on"].desc())

# Add a row number: 1 = latest record
df_social_media = df_social_media.withColumn("row_num", row_number().over(window_spec)) \
             .filter("row_num == 1")\
             .drop("row_num")

df_social_media.count()
# Out:
# Out[13]: 499

# %%
df_support_ticket = (df_support_ticket
                     .withColumnRenamed("ticket_id", "feedback_id")
                     .withColumnRenamed("body", "feedback_text")
                     .withColumn("feedback_on", to_timestamp("created_at", "yyyy-MM-dd'T'HH:mm:ss"))
                     .withColumnRenamed("customer_email","user_email")
                     .withColumn("source", lit("Support Ticket Review"))
                     .withColumn("user_id", lit(None))
                     .withColumn("user_name", lit(None))
                     .withColumn("platform",lit("Support")))
df_support_ticket.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feedback_text</th><th>created_at</th><th>user_email</th><th>status</th><th>subject</th><th>feedback_id</th><th>feedback_on</th><th>source</th><th>user_id</th><th>user_name</th><th>platform</th></tr></thead><tbody><tr><td>Opportunity meeting last would when simple forward direction. Cost consumer effect. West author hope tax several item.</td><td>2025-02-19T19:30:54</td><td>hnicholson@howell.biz</td><td>open</td><td>Ten ever arm find soon feeling box.</td><td>T0000</td><td>2025-02-19T19:30:54.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Owner attention person ever yard process. Would pass best edge. As on well read.</td><td>2025-03-28T15:57:16</td><td>zhayes@reynolds.com</td><td>pending</td><td>Station theory production yeah resource single impact.</td><td>T0001</td><td>2025-03-28T15:57:16.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Early floor project church address century court. Fight evening possible. Hold whom stuff.</td><td>2025-01-28T08:16:31</td><td>zfischer@anderson-haynes.info</td><td>open</td><td>Civil worker both single exist.</td><td>T0002</td><td>2025-01-28T08:16:31.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Wish soldier since music. Left great pass thus last.</td><td>2025-01-05T13:49:08</td><td>amber27@butler.com</td><td>closed</td><td>Enjoy realize image marriage mouth public.</td><td>T0003</td><td>2025-01-05T13:49:08.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>International author finish. Technology different politics source. Fact sense every pass.</td><td>2025-02-24T21:11:13</td><td>hendrixpamela@miller.org</td><td>pending</td><td>Catch design some debate first easy easy.</td><td>T0004</td><td>2025-02-24T21:11:13.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>War soldier tax continue fish west. Law the matter American represent newspaper.</td><td>2025-01-25T01:57:25</td><td>boydedward@williams-jefferson.biz</td><td>closed</td><td>Economy yes detail series yourself view.</td><td>T0005</td><td>2025-01-25T01:57:25.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Recognize measure life attack reduce painting. Represent authority understand career spend protect learn. Minute how green sing sport security store. Capital manager wait daughter local by our.</td><td>2025-03-28T22:35:59</td><td>gibbschristian@yahoo.com</td><td>pending</td><td>Perhaps down treatment information.</td><td>T0006</td><td>2025-03-28T22:35:59.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Take data thus serve us increase quickly this.</td><td>2025-02-28T13:16:41</td><td>patricia21@dawson-gordon.com</td><td>pending</td><td>What per establish us.</td><td>T0007</td><td>2025-02-28T13:16:41.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Least receive realize impact relationship tonight. Run writer hospital. Congress candidate mind guess.</td><td>2025-01-16T07:55:21</td><td>ygonzalez@hotmail.com</td><td>closed</td><td>Security page able form decision why school.</td><td>T0008</td><td>2025-01-16T07:55:21.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>Into method him. Second them suffer pay.</td><td>2025-01-19T21:42:37</td><td>pmurphy@gmail.com</td><td>closed</td><td>Out his thought possible.</td><td>T0009</td><td>2025-01-19T21:42:37.000+0000</td><td>Support Ticket Review</td><td>null</td><td>null</td><td>Support</td></tr><tr><td>One develop rise top according. Sound fly player then television. Point herself religious continue grow. Treatment tend quality course.</td><td>202 ...

# %%
# Define the window
window_spec = Window.partitionBy("user_email").orderBy(df_support_ticket["feedback_on"].desc())

# Add a row number: 1 = latest record
df_support_ticket = df_support_ticket.withColumn("row_num", row_number().over(window_spec)) \
             .filter("row_num == 1") \
             .drop("row_num")

df_support_ticket.count()
# Out:
# Out[15]: 500

# %%
df_website = df_website.select(
    "feedback_id", "user_id", "user_email", "user_name", "feedback_text", "source", "platform", "feedback_on"
)
df_social_media = df_social_media.select(
    "feedback_id", "user_id", "user_email", "user_name", "feedback_text", "source", "platform", "feedback_on"
)
df_support_ticket = df_support_ticket.select(
    "feedback_id", "user_id", "user_email", "user_name", "feedback_text", "source", "platform", "feedback_on"
)

# %%
df_feedback = df_website.union(df_social_media).union(df_support_ticket)
df_feedback.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feedback_id</th><th>user_id</th><th>user_email</th><th>user_name</th><th>feedback_text</th><th>source</th><th>platform</th><th>feedback_on</th></tr></thead><tbody><tr><td>R0243</td><td>00dc580e-7deb-46b8-bfb8-e73998b6bc68</td><td>null</td><td>null</td><td>Loss various debate level fine choose good ball might against threat language less.</td><td>Website Review</td><td>Website name</td><td>2025-03-25T10:06:34.000+0000</td></tr><tr><td>R0437</td><td>00e57abe-fbba-4f5b-b5fb-122d7bef5988</td><td>null</td><td>null</td><td>North note create machine significant light drop standard risk shoulder radio hope table key.</td><td>Website Review</td><td>Website name</td><td>2025-02-22T14:01:12.000+0000</td></tr><tr><td>R0206</td><td>037551b2-cb57-4df8-a7ee-fdaff2f23a67</td><td>null</td><td>null</td><td>Financial realize describe country yourself we use window collection woman ability right toward true rich ago.</td><td>Website Review</td><td>Website name</td><td>2025-04-14T22:42:58.000+0000</td></tr><tr><td>R0225</td><td>03a993a9-a15c-49cd-ac1a-4426b6c55800</td><td>null</td><td>null</td><td>Nothing without look within modern town court offer woman popular store let right change whatever.</td><td>Website Review</td><td>Website name</td><td>2025-01-17T09:24:22.000+0000</td></tr><tr><td>R0480</td><td>03d58f74-acaa-449b-8645-ba9639f5a080</td><td>null</td><td>null</td><td>Natural finally money another whether miss against market particularly politics star stuff.</td><td>Website Review</td><td>Website name</td><td>2025-03-14T08:42:58.000+0000</td></tr><tr><td>R0447</td><td>0497436b-e42e-446e-a2f4-db84dfa100f3</td><td>null</td><td>null</td><td>Organization institution least threat develop small again now upon run partner.</td><td>Website Review</td><td>Website name</td><td>2025-01-17T07:55:53.000+0000</td></tr><tr><td>R0123</td><td>04b320f3-4903-4973-8418-698733897581</td><td>null</td><td>null</td><td>Claim arrive major action member start everything power economy account wide.</td><td>Website Review</td><td>Website name</td><td>2025-01-19T11:49:51.000+0000</td></tr><tr><td>R0192</td><td>04bbe6cd-fa80-4abf-a3d3-adda320c149b</td><td>null</td><td>null</td><td>Three week compare respond perhaps feeling eye indeed find economic should professional including season history.</td><td>Website Review</td><td>Website name</td><td>2025-02-15T03:04:35.000+0000</td></tr><tr><td>R0404</td><td>0589a574-e61f-4766-b58c-2e86921a7c29</td><td>null</td><td>null</td><td>Compare prepare idea effort necessary play summer kid society behavior everyone sell.</td><td>Website Review</td><td>Website name</td><td>2025-03-08T22:43:35.000+0000</td></tr><tr><td>R0311</td><td>0601dbab-414e-4214-8a9c-39b5d0c372b0</td><td>null</td><td>null</td><td>Laugh crime ever think list hot cultural although near model.</td><td>Website Review</td><td>Website name</td><td>2025-02-04T04:15:27.000+0000</td></tr><tr><td>R0440</td><td>07f3ad5f-06e6-45a5-b7a9-4c8bece81b83</td><td>null</td><td>null</td><td>Truth official run company bad worry trade benefit than name top down bag manager.</td><td>Website Review</td><td>Website name</td><td>2025-01-21T17:05:50.000+0000</td></tr><tr><td>R0121</td><td>08b22109-4818-45ed-bb10-812981ad2710</td><td>null</td><td>null</td><td>Body more could knowledge continue opportunity probably structure weight down six bed energy seem must trip.</td><td>Website Review</td><td>Website name</td><td>2025-03-04T14:43:34.000+0000</td></tr><tr><td>R0140</td><td>08f7f561-a956-473b-a602-b0f7ff5798aa</td><td>null</td><td>null</td><td>Little expect process court center subject full hard scene five pick leg.</td><td>Website Review</td><td>Website name</td><td>2025-02-13T07:57:39.000+0000</td></tr><tr><td>R0346</td><td>090e1ffc-2cc7-47b7-88aa-dee4c2252f1b</td><td>null</td><td>null</td><td>Church throw beyond five send accept morning support focus deal onto leave miss  ...

# %%
df_feedback.dropDuplicates(["feedback_id"])
df_feedback.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feedback_id</th><th>user_id</th><th>user_email</th><th>user_name</th><th>feedback_text</th><th>source</th><th>platform</th><th>feedback_on</th></tr></thead><tbody><tr><td>R0243</td><td>00dc580e-7deb-46b8-bfb8-e73998b6bc68</td><td>null</td><td>null</td><td>Loss various debate level fine choose good ball might against threat language less.</td><td>Website Review</td><td>Website name</td><td>2025-03-25T10:06:34.000+0000</td></tr><tr><td>R0437</td><td>00e57abe-fbba-4f5b-b5fb-122d7bef5988</td><td>null</td><td>null</td><td>North note create machine significant light drop standard risk shoulder radio hope table key.</td><td>Website Review</td><td>Website name</td><td>2025-02-22T14:01:12.000+0000</td></tr><tr><td>R0206</td><td>037551b2-cb57-4df8-a7ee-fdaff2f23a67</td><td>null</td><td>null</td><td>Financial realize describe country yourself we use window collection woman ability right toward true rich ago.</td><td>Website Review</td><td>Website name</td><td>2025-04-14T22:42:58.000+0000</td></tr><tr><td>R0225</td><td>03a993a9-a15c-49cd-ac1a-4426b6c55800</td><td>null</td><td>null</td><td>Nothing without look within modern town court offer woman popular store let right change whatever.</td><td>Website Review</td><td>Website name</td><td>2025-01-17T09:24:22.000+0000</td></tr><tr><td>R0480</td><td>03d58f74-acaa-449b-8645-ba9639f5a080</td><td>null</td><td>null</td><td>Natural finally money another whether miss against market particularly politics star stuff.</td><td>Website Review</td><td>Website name</td><td>2025-03-14T08:42:58.000+0000</td></tr><tr><td>R0447</td><td>0497436b-e42e-446e-a2f4-db84dfa100f3</td><td>null</td><td>null</td><td>Organization institution least threat develop small again now upon run partner.</td><td>Website Review</td><td>Website name</td><td>2025-01-17T07:55:53.000+0000</td></tr><tr><td>R0123</td><td>04b320f3-4903-4973-8418-698733897581</td><td>null</td><td>null</td><td>Claim arrive major action member start everything power economy account wide.</td><td>Website Review</td><td>Website name</td><td>2025-01-19T11:49:51.000+0000</td></tr><tr><td>R0192</td><td>04bbe6cd-fa80-4abf-a3d3-adda320c149b</td><td>null</td><td>null</td><td>Three week compare respond perhaps feeling eye indeed find economic should professional including season history.</td><td>Website Review</td><td>Website name</td><td>2025-02-15T03:04:35.000+0000</td></tr><tr><td>R0404</td><td>0589a574-e61f-4766-b58c-2e86921a7c29</td><td>null</td><td>null</td><td>Compare prepare idea effort necessary play summer kid society behavior everyone sell.</td><td>Website Review</td><td>Website name</td><td>2025-03-08T22:43:35.000+0000</td></tr><tr><td>R0311</td><td>0601dbab-414e-4214-8a9c-39b5d0c372b0</td><td>null</td><td>null</td><td>Laugh crime ever think list hot cultural although near model.</td><td>Website Review</td><td>Website name</td><td>2025-02-04T04:15:27.000+0000</td></tr><tr><td>R0440</td><td>07f3ad5f-06e6-45a5-b7a9-4c8bece81b83</td><td>null</td><td>null</td><td>Truth official run company bad worry trade benefit than name top down bag manager.</td><td>Website Review</td><td>Website name</td><td>2025-01-21T17:05:50.000+0000</td></tr><tr><td>R0121</td><td>08b22109-4818-45ed-bb10-812981ad2710</td><td>null</td><td>null</td><td>Body more could knowledge continue opportunity probably structure weight down six bed energy seem must trip.</td><td>Website Review</td><td>Website name</td><td>2025-03-04T14:43:34.000+0000</td></tr><tr><td>R0140</td><td>08f7f561-a956-473b-a602-b0f7ff5798aa</td><td>null</td><td>null</td><td>Little expect process court center subject full hard scene five pick leg.</td><td>Website Review</td><td>Website name</td><td>2025-02-13T07:57:39.000+0000</td></tr><tr><td>R0346</td><td>090e1ffc-2cc7-47b7-88aa-dee4c2252f1b</td><td>null</td><td>null</td><td>Church throw beyond five send accept morning support focus deal onto leave miss  ...

# %%
window_spec = Window.partitionBy("feedback_text").orderBy(df_feedback["feedback_on"].desc())

# Add a row number: 1 = latest record
df_feedback = df_feedback.withColumn("row_num", row_number().over(window_spec)) \
             .filter("row_num == 1") \
             .drop("row_num")

df_feedback.count()
# Out:
# Out[19]: 1499

# %%
df_feedback.filter(col("feedback_on").isNotNull()).count()
# Out:
# Out[20]: 1499

# %%
df_feedback.write.mode("overwrite").partitionBy("source").parquet("/FileStore/feedback_data/")

# %%
display(dbutils.fs.ls("/FileStore/feedback_data/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/feedback_data/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1745863655000</td></tr><tr><td>dbfs:/FileStore/feedback_data/_committed_8032823988985346839</td><td>_committed_8032823988985346839</td><td>35</td><td>1745782198000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/</td><td>source=Social Media Review/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Support Ticket Review/</td><td>source=Support Ticket Review/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Website Review/</td><td>source=Website Review/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("/FileStore/feedback_data/source=Social Media Review/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_committed_4161119589937171557</td><td>_committed_4161119589937171557</td><td>223</td><td>1745782758000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_committed_466484174487865200</td><td>_committed_466484174487865200</td><td>220</td><td>1745863655000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_committed_7622164897269266821</td><td>_committed_7622164897269266821</td><td>223</td><td>1745782612000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_committed_8032823988985346839</td><td>_committed_8032823988985346839</td><td>233</td><td>1745782198000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_committed_842182825592865612</td><td>_committed_842182825592865612</td><td>222</td><td>1745783647000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/_started_466484174487865200</td><td>_started_466484174487865200</td><td>0</td><td>1745863652000</td></tr><tr><td>dbfs:/FileStore/feedback_data/source=Social Media Review/part-00000-tid-466484174487865200-8af8bc81-ad7a-4d4f-90b2-439e3759e232-60-1.c000.snappy.parquet</td><td>part-00000-tid-466484174487865200-8af8bc81-ad7a-4d4f-90b2-439e3759e232-60-1.c000.snappy.parquet</td><td>45536</td><td>1745863654000</td></tr></tbody></table></div>

# %%
df_parquet_Social_media = spark.read.parquet("/FileStore/feedback_data/source=Social Media Review/part-00000-tid-466484174487865200-8af8bc81-ad7a-4d4f-90b2-439e3759e232-60-1.c000.snappy.parquet")
df_parquet_Social_media.show()
# Out:
# +-----------+-------+----------+---------------+--------------------+---------+-------------------+
# |feedback_id|user_id|user_email|      user_name|       feedback_text| platform|        feedback_on|
# +-----------+-------+----------+---------------+--------------------+---------+-------------------+
# |      S0288|   null|      null|        amber56|Able a within blu...|  Twitter|2025-01-16 03:51:40|
# |      S0343|   null|      null|        ehughes|Able draw police....|  Twitter|2025-01-05 21:04:33|
# |      S0218|   null|      null|        iduncan|Above listen I ge...|  Twitter|2025-02-04 22:43:54|
# |      S0408|   null|      null| humphreywesley|Accept drop memor...|  Twitter|2025-03-26 18:57:38|
# |      S0443|   null|      null|       mwheeler|According cut ste...|  Twitter|2025-04-07 07:10:32|
# |      S0187|   null|      null|  douglascooper|According meet mo...|Instagram|2025-02-21 04:05:24|
# |      S0086|   null|      null| donaldgarrison|Across difficult ...| Facebook|2025-02-21 23:29:47|
# |      S0425|   null|      null|         yhodge|Action language o...|  Twitter|2025-01-06 04:15:08|
# |      S0204|   null|      null|       cmcmahon|Address better fi...|  Twitter|2025-02-09 05:18:34|
# |      S0268|   null|      null| wallacetimothy|Admit recent race...|Instagram|2025-01-16 04:10:13|
# |      S0098|   null|      null|   riverasteven|Affect leader tot...|  Twitter|2025-01-20 05:12:56|
# |      S0375|   null|      null|      wstafford|After low none he...|Instagram|2025-03-28 01:17:06|
# |      S0478|   null|      null|   pricecharles|Again plan seat h...|Instagram|2025-03-13 08:35:10|
# |      S0301|   null|      null| kimberlymiller|Against pattern s...| Facebook|2025-01-07 21:59:50|
# |      S0128|   null|      null|mckinneypatrick|Ago concern with ...|Instagram|2025-01-22 13:33:10|
# |      S0319|   null|      null|      matthew90|Air company us si...|Instagram|2025-04-05 23:27:16|
# |      S0322|   null|      null|         kbrown|All development p...|  Twitter|2025-03-15 13:52:13|
# |      S0183|   null|      null|       dspencer|Almost take actio...| Facebook|2025-02-28 20:37:36|
# |      S0168|   null|      null|         leah81|Alone security re...|  Twitter|2025-02-18 15:46:36|
# |      S0399|   null|      null|         rlewis|Amount however on...|Instagram|2025-03-06 02:39:49|
# +-----------+-------+----------+---------------+--------------------+---------+-------------------+
# only showing top 20 rows

# %%
df_parquet_Social_media.count()
# Out:
# Out[26]: 499
